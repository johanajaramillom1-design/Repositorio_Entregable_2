# %% [markdown]
# <a href="https://colab.research.google.com/github/johanajaramillom1-design/Repositorio_Entregable_2/blob/master/Pandas_DataFrames_2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Pandas

import pandas as pd

# 1. Series

s = pd.Series([10, 20, 30, 40, 50], name="edades")
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# Name: edades, dtype: int64

# %%
# 2. DataFrame desde diccionario

df = pd.DataFrame({
    "nombre": ["Juan", "María", "Pedro", "Ana", "Luis"],
    "edad": [25, 30, 35, 40, 45],
    "Nota": [3.5, 4.2, 4.5, 5, 2.5]
})

print(df)
# Out:
#   nombre  edad  Nota
# 0   Juan    25   3.5
# 1  María    30   4.2
# 2  Pedro    35   4.5
# 3    Ana    40   5.0
# 4   Luis    45   2.5

# %%
# 2. Leer dataFrame(tablas, bases de datos.. etc)

#df = pd.read_json("datos.json")

url_drugs = "https://www.datos.gov.co/resource/vwwf-4ftk.json"
df_drugs = pd.read_json(url_drugs)

df_drugs.head()
# Out:
#    expediente                      producto  \
# 0    19916871   CENTRUM SILVER CON LUTEINA.
# 1    20021168     ACICLOVIR800 MG TABLE TAS
# 2      224165                CENTRUM JUNIOR
# 3    19900530               MAXITROL ® PLUS
# 4    19968974  CALCIUM600. VITAMIN DTABLETS
#
#                                 titular        registrosanitario  \
# 0                         PFIZER S.A.S.  INVIMA 2011M-0000632-R1
# 1  LABORATORIOSRICHMOND COLOMBIA S.A.S.     INVIMA 2011M-0012292
# 2                         PFIZER S.A.S.  INVIMA 2008 M-007219 R1
# 3               ALCON LABORATORIES INC.          INVIMA M-012628
# 4    GOOD`N NATURAL MANUFACTURING CORP.     INVIMA 2007M-0006731
#
#            fechaexpedicion         fechavencimiento estadoregistro  \
# 0  2001-10-18T00:00:00.000  2016-09-06T00:00:00.000        Vencido
# 1  2011-06-20T00:00:00.000  2016-07-12T00:00:00.000        Vencido
# 2  1997-10-17T00:00:00.000  2018-02-13T00:00:00.000        Vencido
# ...

# %%
# 3. como explorar un dataFrame

# cabeza del dataframe
#df_drugs.head()

# cola del dataframe
#df_drugs.tail()

# info general
df_drugs.info()

# estadistica descriptiva
#df_drugs.describe()

# slicing
df_drugs.shape

# columnas
#df_drugs.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 28 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   expediente            1000 non-null   int64
#  1   producto              1000 non-null   object
#  2   titular               1000 non-null   object
#  3   registrosanitario     1000 non-null   object
#  4   fechaexpedicion       999 non-null    object
#  5   fechavencimiento      1000 non-null   object
#  6   estadoregistro        1000 non-null   object
#  7   expedientecum         1000 non-null   int64
#  8   consecutivocum        1000 non-null   int64
#  9   cantidadcum           1000 non-null   float64
#  10  descripcioncomercial  1000 non-null   object
#  11  estadocum             1000 non-null   object
#  12  fechaactivo           1000 non-null   object
#  13  fechainactivo         994 non-null    object
#  14  muestramedica         1000 non-null   object
# ...

# %%
 # 3. Seleccion de datos

 #df_drug["producto"]
df_drugs[["producto", "titular","registrosanitario","fechaexpedicion"]]
# Out:
#                                               producto  \
# 0                          CENTRUM SILVER CON LUTEINA.
# 1                            ACICLOVIR800 MG TABLE TAS
# 2                                       CENTRUM JUNIOR
# 3                                      MAXITROL ® PLUS
# 4                         CALCIUM600. VITAMIN DTABLETS
# ..                                                 ...
# 995                               CENTRUM CON LUTEINA.
# 996                                MIDAZOLAM 5 MG /1ML
# 997  CLINDAMICINA INYECCIONUSP AMPOLLA POR 4 ML ( 1...
# 998                                            MYOFAST
# 999                     UNICAP JR TABLETAS MASTICABLES
#
#                                          titular        registrosanitario  \
# 0                                  PFIZER S.A.S.  INVIMA 2011M-0000632-R1
# 1           LABORATORIOSRICHMOND COLOMBIA S.A.S.     INVIMA 2011M-0012292
# 2                                  PFIZER S.A.S.  INVIMA 2008 M-007219 R1
# ...

# %%
# 4. Selección de datos (indexados)

df_drugs.iloc[600]
# Out:
# expediente                                                       19919672
# producto                                       ARTENSOL® H 80 MG TABLETAS
# titular                                           LABORATORIOS WYETH INC.
# registrosanitario                                    INVIMA 2001M-0000470
# fechaexpedicion                                   2001-08-14T00:00:00.000
# fechavencimiento                                  2011-08-27T00:00:00.000
# estadoregistro                                                    Vencido
# expedientecum                                                    19919672
# consecutivocum                                                          6
# cantidadcum                                                          50.0
# descripcioncomercial    BLISTER PVC / PE / PVDC / ALUMINIO. EN CAJA PO...
# estadocum                                                        Inactivo
# fechaactivo                                       2007-01-29T00:00:00.000
# ...

# %%
# 5. filtros

# df_drugs[df_drugs["expediente"] > 11246]
# df_drugs[(df_drugs["expediente"] > 10246) & (df_drugs["producto"] == "CENTRUM CON LUTEINA")]
df_drugs[(df_drugs["expediente"] > 10246) | (df_drugs["producto"] == "CENTRUM CON LUTEINA")]
# df_drugs[(df_drugs["expediente"] > 10246) ~ (df_drugs["producto"] == "CENTRUM CON LUTEINA")]
# Out:
#      expediente                                           producto  \
# 0      19916871                        CENTRUM SILVER CON LUTEINA.
# 1      20021168                          ACICLOVIR800 MG TABLE TAS
# 2        224165                                     CENTRUM JUNIOR
# 3      19900530                                    MAXITROL ® PLUS
# 4      19968974                       CALCIUM600. VITAMIN DTABLETS
# ..          ...                                                ...
# 995    19917963                               CENTRUM CON LUTEINA.
# 996    19959404                                MIDAZOLAM 5 MG /1ML
# 997    19968150  CLINDAMICINA INYECCIONUSP AMPOLLA POR 4 ML ( 1...
# 998    19956235                                            MYOFAST
# 999      225101                     UNICAP JR TABLETAS MASTICABLES
#
#                                          titular        registrosanitario  \
# 0                                  PFIZER S.A.S.  INVIMA 2011M-0000632-R1
# ...

# %%
# 6. operaciones con columnas

df_drugs["expediente2"] = df_drugs["expediente"] * 2
print(df_drugs["expediente2"])
# Out:
# 0      79667484
# 1      80084672
# 2        896660
# 3      79602120
# 4      79875896
#          ...
# 995    79671852
# 996    79837616
# 997    79872600
# 998    79824940
# 999      900404
# Name: expediente2, Length: 1000, dtype: int64

# %%
# 7.manejo de valores faltantes

# 7.1. Ver nulos
df_total.isnull().sum()

# 7.2. Imputar numéricos
num_cols = df_total.select_dtypes(include=['number']).columns
df_total[num_cols] = df_total[num_cols].fillna(df_total[num_cols].median())

# 7.3. Imputar texto/categóricos
cat_cols = df_total.select_dtypes(include=['int64']).columns
df_total[cat_cols] = df_total[cat_cols].fillna("Sin dato")

# 7.4. Revisar nulos final
df_total.isnull().sum()
# Out:
# expediente              0
# producto                0
# titular                 0
# registrosanitario       0
# fechaexpedicion         0
# fechavencimiento        0
# estadoregistro          0
# expedientecum           0
# consecutivocum          0
# cantidadcum             0
# descripcioncomercial    0
# estadocum               0
# fechaactivo             0
# fechainactivo           0
# muestramedica           0
# unidad                  0
# atc                     0
# descripcionatc          0
# viaadministracion       0
# concentracion           0
# principioactivo         0
# unidadmedida            0
# cantidad                0
# unidadreferencia        0
# formafarmaceutica       0
# nombrerol               0
# tiporol                 0
# modalidad               0
# ium                     0
# dtype: int64

# %%
# 8. ordenar datos

df_drugs.sort_values("expediente")
# Out:
#      expediente                                           producto  \
# 496       13118               ISAFORT RETARD CAPSULAS DURAS 240 MG
# 721       16044                                     CIPROFLOXACINO
# 870       20654               ORAVAX (CLORPROMAZINA ITALMEX 25 MG)
# 492       23776              LIPOVENOES L.P.R. EMULSION INYECTABLE
# 28        31992                                ROBIPROFEN TABLETAS
# ..          ...                                                ...
# 393    40207484                             SERECOR® FORTE DPI 100
# 141    40215118                                         RUX® 20 MG
# 677    40219430       SUERO ORAL 75 ® SALES DE REHIDRATACION ORAL.
# 781    40285132  LACTATO DE RINGER SOLUCIÓN INYECTABLE (SOLUCIÓ...
# 272    40490278                                          COMIRNATY
#
#                                                titular     registrosanitario  \
# 496                                       PROCAPS S.A.              M-005575
# ...
